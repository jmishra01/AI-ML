# %% [markdown]
# <a href="https://colab.research.google.com/github/jmishra01/AI-ML/blob/main/ML_01_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data url & file name
data = "https://raw.githubusercontent.com/jmishra01/AI-ML/refs/heads/main/data/Real-estate.csv"
file_name = "Real-estate.csv"

# %%
# Dowload csv file using requests library
import requests

res = requests.get(data)
if res.status_code == 200:
    with open(file_name, 'wb') as f:
        f.write(res.content)

# %%
# Display first 5 rows
# !head -n 5 Real-estate.csv
# Out:
# No,X1 transaction date,X2 house age,X3 distance to the nearest MRT station,X4 number of convenience stores,X5 latitude,X6 longitude,Y house price of unit area
# 1,2012.917,32,84.87882,10,24.98298,121.54024,37.9
# 2,2012.917,19.5,306.5947,9,24.98034,121.53951,42.2
# 3,2013.583,13.3,561.9845,5,24.98746,121.54391,47.3
# 4,2013.500,13.3,561.9845,5,24.98746,121.54391,54.8

# %%
# Read csv file, and create pandas dataframe
df = pd.read_csv(file_name)

# %%
columns = ["No", "trans-date", "house-age", "dist-mrt-stn", "#-stores", "lat", "lng", "price-per-unit"]
df.columns = columns
df = df[columns[1:]]

# %%
plt.scatter(df["house-age"], df["price-per-unit"])
plt.show()
